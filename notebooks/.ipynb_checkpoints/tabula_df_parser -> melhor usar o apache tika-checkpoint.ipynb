# %%
import pandas as pd
import tabula

# %%
pdf_to_examine_folder = "/home/arthur/personal_projects/clone_scrapy_celesc_v2/scrapy_applications_v2/project_folder/downloads/"
pdf_name = "liro_liro_sturt_liro1"

complete_pdf = pdf_to_examine_folder + pdf_name

# %%
tabula_loaded_pdf = tabula.read_pdf(
    complete_pdf,
    pages = 'all',
    multiple_tables=True
)
len(tabula_loaded_pdf)
# Out:
# 2

# %%
df = tabula_loaded_pdf[0]
df
# Out:
#                   No DA UNIDADE\rCONSUMIDORA\r2574250  VENCIMENTO\r24/06/2016  \
# 0                                                 NaN                     NaN
# 1   ATENDIMENTO AO CLIENTE\rNAL / TRIFASICLOIGUE\r...                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4   Dados do FaturamentoFaturadoTarifa (R$)Valor (...                     NaN
# 5                                                 NaN            DISTRIBUICAO
# 6                                                 NaN                  266,08
# 7   INCIDIRÃO SOBRE A CONTA PAGA APÓS O VENCIMENTO...                     NaN
# 8                                                 NaN  INFORMAÇÃO DE TRIBUTOS
# 9                                                 NaN                TRIBUTOS
# 10                                                NaN                    ICMS
# 11                                                NaN                  COFINS
# 12                                                NaN               PIS/PASEP
#
#          Unnamed: 0                           Unnamed: 1        Unnamed: 2  \
# 0               NaN    CONSUMO TOTAL FATURADO\r3.150 kWh               NaN
# 1               NaN                                  NaN               NaN
# 2               NaN  VALOR ATÉ O VENCIMENTO\rR$ 2.012,00               NaN
# 3               NaN                                  NaN               NaN
# 4               NaN                                  NaN               NaN
# 5    ENC. SETORIAIS                              ENERGIA       TRANSMISSAO
# 6            304,22                               778,09             51,34
# 7               NaN                                  NaN               NaN
# 8               NaN                                  NaN               NaN
# 9   BASE DE CÁLCULO                             ALÍQUOTA  VALOR DO IMPOSTO
# 10       R$2.001,61                               25,00%          R$500,40
# 11       R$2.001,61                                4,17%           R$83,47
# 12       R$2.001,61                                0,90%           R$18,01
#
#    Unnamed: 3      Unnamed: 4
# 0         NaN             NaN
# 1         NaN             NaN
# 2         NaN             NaN
# 3         NaN             NaN
# 4         NaN             NaN
# 5    TRIBUTOS  Soma Demonstr.
# 6      601,88        2.001,61
# 7         NaN             NaN
# 8         NaN             NaN
# 9         NaN             NaN
# 10        NaN             NaN
# 11        NaN             NaN
# 12        NaN             NaN

# %%
df['No DA UNIDADE\rCONSUMIDORA\r2574250'][4] # util
# Out:
# 'Dados do FaturamentoFaturadoTarifa (R$)Valor (R$\rConsumo3.1500,6354322.001,6\rSubtotal (R$)2.001,6\rLançamentos e Serviços\rCosip10,3\rSubtotal (R$)10,3\rda Via\rComposição do Preço em R$ (Art. 31, Res. 166/05):'

# %%
df['No DA UNIDADE\rCONSUMIDORA\r2574250'][7] # inutil
# Out:
# 'INCIDIRÃO SOBRE A CONTA PAGA APÓS O VENCIMENTO MULTA DE 2%, JUROS DE\rMORA DE 0,0333% AO DIA (CONF. LEI 10.438/02) E ATUALIZAÇÃO MONETÁRIA COM\rBASE NO IGP-M A SEREM INCLUÍDOS NA PRÓXIMA CONTA.'

# %%
df.iloc[
    5:7,
    1:
]
# Out:
#   VENCIMENTO\r24/06/2016      Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 5           DISTRIBUICAO  ENC. SETORIAIS    ENERGIA  TRANSMISSAO   TRIBUTOS
# 6                 266,08          304,22     778,09        51,34     601,88
#
#        Unnamed: 4
# 5  Soma Demonstr.
# 6        2.001,61

# %%
df.iloc[
    9:,
    2:5
]
# Out:
#          Unnamed: 0 Unnamed: 1        Unnamed: 2
# 9   BASE DE CÁLCULO   ALÍQUOTA  VALOR DO IMPOSTO
# 10       R$2.001,61     25,00%          R$500,40
# 11       R$2.001,61      4,17%           R$83,47
# 12       R$2.001,61      0,90%           R$18,01
